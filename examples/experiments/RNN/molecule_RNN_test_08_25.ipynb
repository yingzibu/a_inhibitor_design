# %% [markdown]
# <a href="https://colab.research.google.com/github/yingzibu/a_inhibitor_design/blob/main/exmples/experiments/molecule_RNN_test_08_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/shiwentao00/Molecule-RNN.git --quiet

# %%
! pip install rdkit --quiet
! pip install selfies --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.7/29.7 MB 42.0 MB/s eta 0:00:00

# %%
cd Molecule-RNN
# Out:
# /content/Molecule-RNN

# %%
import torch
import re
from tqdm import tqdm
import yaml
import selfies as sf
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence

# import yaml
import os
# import torch
import torch.nn as nn
from torch.nn.utils.rnn import pack_padded_sequence
from torch.optim.lr_scheduler import ReduceLROnPlateau
from rdkit import Chem
# import selfies as sf
from rdkit import rdBase
rdBase.DisableLog('rdApp.error')

# %%
selfie_vocab_path = '/content/Molecule-RNN/vocab/selfies_merged_vocab.yaml'

class SELFIEVocab:
    def __init__(self, vocab_path):
        self.name ='selfies'
        with open(vocab_path, 'r') as f: self.vocab = yaml.full_load(f)
        self.int2token = {value:key for key, value in self.vocab.items()}
    def tokenize_smiles(self, mol): #mol is selfie actually
        ints = [self.vocab['<sos>']]
        selfies_list = list(sf.split_selfies(mol))
        ints += [self.vocab[token] for token in selfies_list]
        ints.append(self.vocab['<eos>'])
        return ints
    def combine_list(self, selfies): return "".join(selfies)

import pandas as pd

class SMILESDataset(Dataset):
    def __init__(self, smiles_file, percentage, vocab):
        super(SMILESDataset, self).__init__()
        assert (0<percentage<=1)
        self.percentage = percentage
        self.vocab = vocab
        if smiles_file.split('.')[-1] == 'smi':
            self.data = self.read_smiles_file(smiles_file)
        elif smiles_file.split('.')[-1] == 'csv':
            self.data = self.read_csv_file(smiles_file)
        print('total number of SMILES loaded: ', len(self.data))

        if self.vocab.name == 'selfies':
            self.data = self.smi2sf()
            print('total valid SELFIES:', len(self.data))
    def __getitem__(self, index):
        s_mol = self.data[index]
        vec_mol = self.vocab.tokenize_smiles(s_mol)
        return vec_mol

    def __len__(self): return len(self.data)

    def smi2sf(self):
        smiles = self.data
        sfs = []
        for i in tqdm(smiles, total=len(smiles)):
            try:
                s_ = sf.encoder(i)
                if s_ is not None: sfs.append(s_)
            except: pass
        return sfs



    def read_smiles_file(self, path):
        with open(path, 'r') as f:
            smiles = [line.strip("\n") for line in f.readlines()]
        num_data = len(smiles)
        return smiles[0:int(num_data*self.percentage)]

    def read_csv_file(self, path):
        data = pd.read_csv(path)
        for i in ['Smiles', 'smiles', 'SMILES']:
            if i in data.columns:
                smiles = data[i].tolist()
                num_data = len(smiles)
                return smiles[0:int(num_data*self.percentage)]

smile_dir = '/content/Molecule-RNN/dataset/chembl28-cleaned.smi'
selfie_vocab_path = '/content/Molecule-RNN/vocab/selfies_merged_vocab.yaml'

def dataloader_gen(percentage, batch_size, PADDING_IDX, shuffle,
                   dataset_dir=smile_dir, which_vocab='selfies',
                   vocab_path=selfie_vocab_path, drop_last=True):
    print('which_vocab:', which_vocab)
    if which_vocab == 'selfies':
        vocab = SELFIEVocab(vocab_path)
        dataset = SMILESDataset(dataset_dir, percentage, vocab)
    else:
        dataset = None
        vocab = None

    def pad_collate(batch):
        lengths = [len(x) for x in batch]
        batch = [torch.tensor(x, dtype=torch.long) for x in batch]
        x_padded = pad_sequence(batch, batch_first=True,
                                padding_value=PADDING_IDX)
        return x_padded, lengths

    dataloader = DataLoader(dataset=dataset, batch_size=batch_size,
                            shuffle=shuffle, drop_last=drop_last,
                            collate_fn=pad_collate)
    return dataloader, len(dataset)

# %%
rnn_config = {
    'num_embeddings': 78,
    'embedding_dim': 256,
    'rnn_type': "GRU",

    "input_size": 256,
    'hidden_size': 512,
    'num_layers': 3,
    'dropout': 0,

    "batch_size": 512,
    'shuffle': True,
    'num_epoch': 10,
    'which_optimizer': 'adam',
    'learning_rate': 0.001,
    'weight_decay': 1.0e-4
}

# %%
def sample(model, vocab, batch_size):
    model.eval()
    sample_ints = model.sample(batch_size=batch_size, vocab=vocab).tolist()
    molecules = []
    for ints in sample_ints:
        mol = []
        for x in ints:
            if vocab.int2token[x] == '<eos>': break
            else: mol.append(vocab.int2token[x])
        string_mol = "".join(mol)
        molecules.append(string_mol)
    if vocab.name == 'selfies':
        molecules = [sf.decoder(x) for x in molecules]
    return molecules


def compute_valid_rate(molecules):
    num_valid, num_invalid = 0, 0
    valid_mols = set()
    for i in molecules:
        mol = Chem.MolFromSmiles(i)
        if mol is None: num_invalid +=1
        else:
            num_valid += 1
            valid_mols.add(i)
    assert len(molecules) == num_valid + num_invalid
    unique_num = len(valid_mols)
    # print(unique_num)
    valid_rate = num_valid / len(molecules)
    unique_rate = unique_num / len(molecules)
    return valid_rate, unique_rate

import torch
def save_model(model, path):
    torch.save(model.state_dict(), path)

def load_model(model, path):
    cuda = torch.cuda.is_available()
    if cuda: device = 'cuda'
    else: device = 'cpu'
    model.load_state_dict(torch.load(path, map_location=device))

# %%
cuda = torch.cuda.is_available()
if cuda: device = 'cuda'
else: device = 'cpu'

out_dir = 'model_save/'
if not os.path.exists(out_dir): os.makedirs(out_dir)

with open(out_dir+'config.yaml', 'w') as f: yaml.dump(rnn_config, f)

smile_dir = '/content/Molecule-RNN/dataset/chembl28-cleaned.smi'
selfie_vocab_path = '/content/Molecule-RNN/vocab/selfies_merged_vocab.yaml'

# %%
print(rnn_config)
dataset_dir = smile_dir
which_vocab = 'selfies'
vocab_path = selfie_vocab_path

batch_size = rnn_config['batch_size']
shuffle = rnn_config['shuffle']
PADDING_IDX = rnn_config['num_embeddings']-1
num_workers = os.cpu_count()
print('number of workers to load data:', num_workers)
print('which vocab to use: ', which_vocab)
vocab = SELFIEVocab(selfie_vocab_path)
# Out:
# {'num_embeddings': 78, 'embedding_dim': 256, 'rnn_type': 'GRU', 'input_size': 256, 'hidden_size': 512, 'num_layers': 3, 'dropout': 0, 'batch_size': 512, 'shuffle': True, 'num_epoch': 10, 'which_optimizer': 'adam', 'learning_rate': 0.001, 'weight_decay': 0.0001}
# number of workers to load data: 8
# which vocab to use:  selfies

# %%
percentage = 0.01

dataloader, train_size = dataloader_gen(percentage, batch_size, PADDING_IDX,
                                        shuffle, drop_last=False)
# Out:
# which_vocab: selfies
# total number of SMILES loaded:  5382
# 100%|██████████| 5382/5382 [00:03<00:00, 1669.58it/s]
# total valid SELFIES: 5382

# %%
sos = torch.ones([batch_size, 1], dtype=torch.long, device=device)

# %%
import torch
import torch.nn as nn
from torch.nn.utils.rnn import pack_padded_sequence
from torch.nn.functional import softmax
import torch.nn.functional as F

class RNN(nn.Module):
    def __init__(self, rnn_config):
        super(RNN, self).__init__()

        self.emb = nn.Embedding(num_embeddings = rnn_config['num_embeddings'],
                                embedding_dim = rnn_config['embedding_dim'],
                                padding_idx = rnn_config['num_embeddings'] - 1)

        if rnn_config['rnn_type'] == 'LSTM':
            self.rnn = nn.LSTM(input_size = rnn_config['input_size'],
                               hidden_size = rnn_config['hidden_size'],
                               num_layers = rnn_config['num_layers'],
                               batch_first=True, dropout=rnn_config['dropout'])
        elif rnn_config['rnn_type'] == 'GRU':
            self.rnn = nn.GRU(input_size = rnn_config['input_size'],
                            hidden_size = rnn_config['hidden_size'],
                            num_layers = rnn_config['num_layers'],
                            batch_first=True, dropout=rnn_config['dropout'])
        else: raise ValueError('rnn_type should be LSTM or GRU')
        hid_dim = int(rnn_config['hidden_size']/2)
        self.linear = nn.Linear(rnn_config['hidden_size'], hid_dim)

        self.mu = nn.Linear(hid_dim, hid_dim)

        self.decode = nn.Linear(hid_dim, rnn_config['num_embeddings']-2)

    def forward(self, data, lengths):
        # print('data shape: ', data.shape) # [batch_size, ...]
        embeddings = self.emb(data)
        # print('emb shape:', embeddings.shape) #[batch_size, ..., embedding_dim]
        # emb before pack:               torch.Size([512, 115 (can change), 256])


        embeddings = pack_padded_sequence(input=embeddings, lengths=lengths,
                                    batch_first=True, enforce_sorted=False)



        # print('emb after pack: ', embeddings.shape)
        # cannot shape pack_padded sequence

        embeddings, _ = self.rnn(embeddings)
        # print('emb after rnn: ', embeddings.shape)
        # AttributeError: 'PackedSequence' object has no attribute 'shape'

        embeddings = self.linear(embeddings.data)


        # print('emb after linear: ', embeddings.shape)
        # [sum_of_mol_len, num_embedding-2]

        embeddings = self.mu(embeddings)
        embeddings = F.relu(embeddings)
        return self.decode(embeddings)

    def sample(self, batch_size, vocab, max_length=140):
        start_int = vocab.vocab['<sos>']
        if torch.cuda.is_available(): device='cuda'
        else: device = 'cpu'
        sos = torch.ones([batch_size, 1], dtype=torch.long, device=device)
        sos = sos * start_int
        output = []
        x = self.emb(sos)

        x, hidden = self.rnn(x)
        x = self.linear(x)
        x = F.relu(self.mu(x))
        x = self.decode(x)
        x = softmax(x, dim=-1)
        x = torch.multinomial(x.squeeze(), 1)
        output.append(x)
        # x = sos
        finish = torch.zeros(batch_size, dtype=torch.bool).to(device)
        for _ in range(max_length):
            x = self.emb(x)
            x, hidden = self.rnn(x, hidden)
            x = self.linear(x)
            x = F.relu(self.mu(x))
            x = self.decode(x)
            x = softmax(x, dim=-1)

            x = torch.multinomial(x.squeeze(), 1)
            output.append(x)
            eos_sampled = (x==vocab.vocab['<eos>']).data
            finish = torch.logical_or(finish, eos_sampled.squeeze())
            if torch.all(finish):
                return torch.cat(output, -1)
        return torch.cat(output, -1)

# %%
model = RNN(rnn_config).to(device)
learning_rate = rnn_config['learning_rate']
weight_decay = rnn_config['weight_decay']
loss_function = nn.CrossEntropyLoss(reduction='sum')

if rnn_config['which_optimizer'] == 'adam':
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate,
                                 weight_decay=weight_decay, amsgrad=True)
elif rnn_config['which_optimizer'] == 'sgd':
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate,
                                weight_decay=weight_decay, momentum=0.9)
elif rnn_config['which_optimizer'] == 'adamw':
    optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate,
                                 weight_decay=weight_decay, amsgrad=True)
else: raise ValueError('wrong optimizer. should be adam, sgd or adamw')

scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5,
                              cooldown=10, min_lr=1e-4, verbose=True)

# %%
train_losses = []
best_valid_rate = 0
num_epoch = rnn_config['num_epoch']
print(f'begin training {num_epoch} epochs')
model_names = []
best_epoch = 0
# Out:
# begin training 10 epochs

# %%
if best_epoch != 0:
    load_model(model, out_dir + f'epoch_{best_epoch}.pt')

# device = 'cuda'

for epoch in range(1, 1+num_epoch):
    model.train()
    train_loss = 0
    for data, lengths in tqdm(dataloader, total=len(dataloader),
                              desc=f'epoch {epoch}'): # batch_size = 512
        # print(lengths)
        lengths = [l-1 for l in lengths]
        optimizer.zero_grad()
        if cuda: data = data.cuda()
        # data = data.to(device)
        preds = model(data, lengths)
        # print(preds.shape)

        targets = pack_padded_sequence(
            data[:, 1:], lengths, batch_first=True, enforce_sorted=False).data
        # targets = data


        # preds: [num, len_alphabet-2], target: [num]
        # print('hre pred, target, ', preds.shape, targets.shape)
        # preds = preds.view(-1, preds.shape[-1])
        # targets = data
        # targets = targets.reshape(-1)
        loss = loss_function(preds, targets)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    train_losses.append(train_loss/train_size)
    print(f'epoch {epoch}, train_loss: {train_losses[-1]:.3f}')
    scheduler.step(train_losses[-1])

    sampled_molecules = sample(model, vocab, batch_size=1024)
    valid, unique = compute_valid_rate(sampled_molecules)
    print(f'valid:  {(valid * 100):.3f} % | unique: {(unique * 100):.3f} %')
    if valid > best_valid_rate:
        best_epoch = epoch
        trained_model_dir = out_dir + f'epoch_{epoch}.pt'
        print(f'save model: ', trained_model_dir)
        save_model(model, trained_model_dir)
        model_names.append(trained_model_dir)
        while len(model_names) > 10:
            try:
                remove_name = model_names.pop(0)
                print('remove ', remove_name)
                os.remove(remove_name)
            except: print(f'error remove {model_names[0]}')
# Out:
# epoch 1: 100%|██████████| 11/11 [00:02<00:00,  4.03it/s]
# epoch 1, train_loss: 83.514
# valid:  100.000 % | unique: 96.777 %
# save model:  model_save/epoch_1.pt
# epoch 2: 100%|██████████| 11/11 [00:02<00:00,  4.05it/s]
# epoch 2, train_loss: 81.194
# valid:  100.000 % | unique: 97.168 %
# save model:  model_save/epoch_2.pt
# epoch 3: 100%|██████████| 11/11 [00:02<00:00,  4.04it/s]
# epoch 3, train_loss: 79.878
# valid:  100.000 % | unique: 98.438 %
# save model:  model_save/epoch_3.pt
# epoch 4: 100%|██████████| 11/11 [00:02<00:00,  4.02it/s]
# epoch 4, train_loss: 77.031
# valid:  100.000 % | unique: 98.438 %
# save model:  model_save/epoch_4.pt
# epoch 5: 100%|██████████| 11/11 [00:02<00:00,  4.02it/s]
# epoch 5, train_loss: 75.080
# valid:  100.000 % | unique: 98.730 %
# save model:  model_save/epoch_5.pt
# epoch 6: 100%|██████████| 11/11 [00:02<00:00,  3.99it/s]
# epoch 6, train_loss: 73.271
# valid:  100.000 % | unique: 99.414 %
# save model:  model_save/epoch_6.pt
# epoch 7: 100%|██████████| 11/11 [00:02<00:00,  3.96it/s]
# epoch 7, train_loss: 71.706
# valid:  100.000 % | unique: 99.316 %
# save model:  model_save/epoch_7.pt
# epoch 8: 100%|██████████| 11/11 [00:02<00:00,  3.97it/s]
# epoch 8, train_loss: 71.171
# valid:  100.000 % | unique: 99.609 %
# save model:  model_save/epoch_8.pt
# epoch 9: 100%|██████████| 11/11 [00:02<00:00,  3.95it/s]
# epoch 9, train_loss: 69.682
# valid:  100.000 % | unique: 99.512 %
# save model:  model_save/epoch_9.pt
# epoch 10: 100%|██████████| 11/11 [00:02<00:00,  3.94it/s]
# epoch 10, train_loss: 68.128
# valid:  100.000 % | unique: 99.414 %
# save model:  model_save/epoch_10.pt

# %%
best_dir = out_dir + f'epoch_{best_epoch}.pt'
with open(out_dir +'config.yaml', 'r') as f: config = yaml.full_load(f)
model = RNN(config).to(device)
load_model(model, best_dir)
model.eval()
num_batches = 3
from rdkit.Chem.Draw import IPythonConsole, MolsToGridImage
import random
import math
from rdkit import Chem
mol_conv = Chem.MolFromSmiles

for _ in tqdm(range(num_batches)):
    sampled_ints = model.sample(batch_size=batch_size,
                                vocab=vocab).tolist()
    mols = []
    for ints in sampled_ints:
        s_mol = []
        for x in ints:
            if vocab.int2token[x] =='<eos>':break
            else: s_mol.append(vocab.int2token[x])
        mols.append("".join(s_mol))
    mols = [sf.decoder(x) for x in mols]
    valid, unique = compute_valid_rate(mols)
    print(f'\n valid:  {(valid * 100):.3f} % | unique: {(unique * 100):.3f} %')
    all_correct_molecules = set(mols)
    MAX_GRID = 16
    show_num = min(len(all_correct_molecules), MAX_GRID)
    selected_smiles = random.choices([*all_correct_molecules], k=show_num)
    molecules = [mol_conv(i) for i in selected_smiles]

    img = MolsToGridImage(
        [m for m in molecules if m is not None],
        molsPerRow=int(math.sqrt(MAX_GRID)),
        subImgSize=(250, 150),  returnPNG=False)
    display(img)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
#  valid:  100.000 % | unique: 99.805 %
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x600>
#  33%|███▎      | 1/3 [00:00<00:01,  1.68it/s]
#  valid:  100.000 % | unique: 99.805 %
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x600>
#  67%|██████▋   | 2/3 [00:01<00:00,  1.87it/s]
#  valid:  100.000 % | unique: 100.000 %
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x600>
# 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]

# %%
sampled_ints = model.sample(batch_size=2, vocab=vocab).tolist()
print(len(sampled_ints[1]))
mols = []
for ints in sampled_ints:
    s_mol = []
    for x in ints:
        if vocab.int2token[x] =='<eos>':break
        else: s_mol.append(vocab.int2token[x])
    mols.append("".join(s_mol))
mols = [sf.decoder(x) for x in mols]
valid, unique = compute_valid_rate(mols)
print(f'\n valid:  {(valid * 100):.3f} % | unique: {(unique * 100):.3f} %')
all_correct_molecules = set(mols)
MAX_GRID = 16
show_num = min(len(all_correct_molecules), MAX_GRID)
selected_smiles = random.choices([*all_correct_molecules], k=show_num)
molecules = [mol_conv(i) for i in selected_smiles]
print(selected_smiles)
img = MolsToGridImage(
    [m for m in molecules if m is not None],
    molsPerRow=int(math.sqrt(MAX_GRID)),
    subImgSize=(250, 150),  returnPNG=False)
display(img)
# Out:
# 52
#
#  valid:  100.000 % | unique: 100.000 %
# ['CC1=CC(O)CC1C(C)C2C=CC(O)=CC(=O)OC=N2', 'CC(CCCC(C)CC)CCNCCNCCC(=O)NC=C1N=C[NH1]C=CC=CC1C']
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x150>

# %%
out = []
model.eval()
sample_size = 10
a = torch.ones([sample_size, 1], dtype=torch.long, device='cuda')
a = a * vocab.vocab['<sos>']

x = model.emb(a)  # []
# print(x.shape)
x, hidden =  model.rnn(x)
x = model.linear(x)
x = F.relu(model.mu(x))
x = model.decode(x)
x = softmax(x, dim=-1)

x = torch.multinomial(x.squeeze(), 1)
# x
out.append(x)
finish = torch.zeros(sample_size, dtype=torch.bool).to('cuda')

for _ in range(140):
    if sample_size == 1: x = x.reshape(1, 1)
    # print(x.shape)
    x = model.emb(x)  # []
    x, _ =  model.rnn(x, hidden)
    x = model.linear(x)
    x = F.relu(model.mu(x))
    x = model.decode(x)
    x = softmax(x, dim=-1)
    x = torch.multinomial(x.squeeze(), 1)
    out.append(x)

    eos_sampled = (x==vocab.vocab['<eos>']).data
    # print(eos_sampled.shape)
    finish = torch.logical_or(finish, eos_sampled.squeeze())
    # print(finish)
    if torch.all(finish):
        if sample_size != 1: a = torch.cat(out, 1).tolist()
        else: a = torch.cat(out).tolist()
a = [torch.cat(out).tolist()] if sample_size == 1 else torch.cat(out, 1).tolist()
# a.shape
# a = torch.cat(out, 1).tolist()
print(len(a[0]))
mols = []




for ints in a:
    s_mol = []
    for x in ints:
        if vocab.int2token[x] =='<eos>':break
        else: s_mol.append(vocab.int2token[x])
        # print(s_mol)
    mols.append("".join(s_mol))

mols = [sf.decoder(x) for x in mols]

valid, unique = compute_valid_rate(mols)
print(f'\n valid:  {(valid * 100):.3f} % | unique: {(unique * 100):.3f} %')
all_correct_molecules = set(mols)
MAX_GRID = 16
show_num = min(len(all_correct_molecules), MAX_GRID)
selected_smiles = random.choices([*all_correct_molecules], k=show_num)
molecules = [mol_conv(i) for i in selected_smiles]

img = MolsToGridImage(
    [m for m in molecules if m is not None],
    molsPerRow=int(math.sqrt(MAX_GRID)),
    subImgSize=(250, 150),  returnPNG=False)
display(img)
# Out:
# tensor([[14],
#         [14],
#         [26],
#         [17],
#         [63],
#         [39],
#         [39],
#         [14],
#         [39],
#         [14]], device='cuda:0')
# 141
#
#  valid:  100.000 % | unique: 100.000 %
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x450>

# %%
out = []
# model.eval()
sample_size = 10
# a = torch.ones([sample_size, 1], dtype=torch.long, device='cuda')
# a = a * vocab.vocab['<sos>']

x = torch.tensor([random.randint(0, 75) for i in range(sample_size)]).reshape([sample_size, 1]).to('cuda')
# x
out.append(x)
finish = torch.zeros(sample_size, dtype=torch.bool).to('cuda')

for _ in range(140):
    x = torch.tensor([random.randint(0, 75) for i in range(sample_size)]).reshape([sample_size, 1]).to('cuda')
# x

    out.append(x)

    eos_sampled = (x==vocab.vocab['<eos>']).data
    # print(eos_sampled.shape)
    finish = torch.logical_or(finish, eos_sampled.squeeze())
    # print(finish)
    if torch.all(finish):
        if sample_size != 1: a = torch.cat(out, 1).tolist()
        else: a = torch.cat(out).tolist()
a = [torch.cat(out).tolist()] if sample_size == 1 else torch.cat(out, 1).tolist()
# a.shape
# a = torch.cat(out, 1).tolist()
print(len(a[0]))
mols = []


for ints in a:
    s_mol = []
    for x in ints:
        if vocab.int2token[x] =='<eos>' :break
        else: s_mol.append(vocab.int2token[x])
    mols.append("".join(s_mol))
print(mols)
mols = [sf.decoder(x) for x in mols]

valid, unique = compute_valid_rate(mols)
print(f'\n valid:  {(valid * 100):.3f} % | unique: {(unique * 100):.3f} %')
all_correct_molecules = set(mols)
MAX_GRID = 16
show_num = min(len(all_correct_molecules), MAX_GRID)
selected_smiles = random.choices([*all_correct_molecules], k=show_num)
molecules = [mol_conv(i) for i in selected_smiles]

img = MolsToGridImage(
    [m for m in molecules if m is not None],
    molsPerRow=int(math.sqrt(MAX_GRID)),
    subImgSize=(250, 150),  returnPNG=False)
display(img)
# Out:
# 141
# ['[=O][SH1][Ring2][Se+1][#Branch1][O-1][#N+1][=O][P][=O][#Branch2][=P][OH0][#N+1][S-1][=Se][#N][BH1-1][S][O+1][=N+1][#Branch2][B-1][#C][B-1][S][P+1][I][=Te+1][Cl][Branch2][C+1][#N+1][Cl+3][I+1][NH2+1][B-1][=SH1][Ring1][=SH1][NH1-1][Ring1][=S+1][=O+1][SH1][=PH1][O+1][#N+1][Ring1][SH1][BH3-1][C+1][OH0][#C][Te][F][S+1][Al][N][=N][Branch1][BH3-1][=S+1][#C][=S][#Branch2][=Te+1][N-1][=As][S-1][Branch2][Na][O-1][B-1][N][C][OH0][Si][O+1][B-1][F][BH2-1][SeH1][#N][=Te+1][=S+1][Se+1][NH2+1][=SH1][OH1+1][PH1][=P+1][C+1][=NH1+1]', '[Ring2][B][Se][C-1][Na][Al][BH1-1][BH1-1][=Branch1][Branch2][BH2-1][Branch2][=Se+1][#Branch2][BH3-1][#Branch1][Si][BH1-1][=Branch1][BH1-1][=S][O+1][OH1+1][#Branch2][SH1][OH0][P][B][=P][Cl+3][#N+1][Ring2][F][NH1+1][P+1][#Branch2][N-1][=P+1][=Se+1][N+1][N-1][=SH1][Branch2][C][P+1][#N+1][F][B-1][N+1][Cl][F][#C-1][#Branch2][NH1+1][=Se]', '[=P][Ring1][=PH1][H][S-1][=As][I][=Ring2][SeH1][=Branch2][NH2+1][=N+1][N+1][NH1-1][#Branch2][BH1-1][S-1][Al][C-1][Si][S][S-1][OH0][#Branch2][=PH1][NH1+1][#Branch1][S][O+1][S-1][BH1-1][=Branch2][#Branch2][Branch1][N+1][N-1][=Se+1][=Ring1][#C][#Branch1][Te][Ring2][#N][PH1][=NH1+1][=Ring1][As][Branch2][Ring2][S-1][#Branch2][S+1][NH1+1][NH1][#N+1][NH1+1][=O+1][Se][#Branch1][N-1][P][H][=NH2+1][Si]', '[N][B-1][=Te+1][NH2+1][SeH1][P+1][N+1][=O+1]', '[NH1-1][=Se][F][=O][Cl][C][C+1][=Te+1][SH1][=N][I][#N][OH0][Cl][BH3-1][SeH1][Na][=SH1][N-1][OH1+1][Ring2][N][O+1][#N+1][=P+1][Na][OH0][F][B-1][I][S][=N][Ring2][#Branch2][=N-1][=Se+1][I+1][=C][C-1][#Branch1][SeH1][=Ring1][#Branch1][#N][#C][Al][N-1][#Branch1][Se+1][S-1][SeH1][I+1][=SH1][=N+1][NH1][=NH1+1][S][NH2+1][=Ring2][Si][=Se+1][BH2-1][S-1][#Branch1][CH1-1][=PH1][=Ring2][PH1][=Branch2][=O][C][CH1-1][B-1][C-1][P][Al][=Ring2][=Ring2][=C][#C][Ring1][=N][NH1][As][Branch1][=C][=Se+1][I][C][=PH1][=O+1][C+1][=S+1][N][=PH1][=Se][Se][=NH1+1][=Se+1][=As][Branch2][=Te+1][Te][F][=N][S-1][Branch1][BH2-1][=P+1][#C-1][=N-1][S+1][Br][=PH1][BH1-1][As][Si][Branch2][#C][=N-1][Se][S-1][Ring1][=PH1][=S+1][=Ring1][=N][H][=O+1][=Branch2][S][NH1+1][Cl][As]', '[=O+1][B][=NH1+1][=N-1][#N+1][=Ring1][O-1][O][=N][#C][#Branch2][#Branch1][#Branch1][=N-1][#N][=N-1][Cl+3][Al][NH1][Cl+3][C+1][B][Si][O+1][Te][=N+1][=NH2+1][=Ring2][Na][=O][=O+1][Se][Si][Ring1][B][#Branch1][S][PH1][Branch2][NH2+1][=O][As][PH1][BH2-1][=N][=O][=PH1][#N+1][=O+1][PH1][B-1][BH1-1][O+1][=Branch2][Branch1][Branch1][BH2-1][O+1][=S+1][#C-1][Se+1][OH0][=P+1][I][=Branch2][SeH1][I][=Ring2][=Branch2][Na][Branch1][Br][C+1][I][=SH1][O+1][N][#C-1][Br][Se+1][N-1][Ring1][O][=O+1][=N][=Branch2][NH1+1][O][Al][=Se][=N-1][B][=NH1+1][=NH2+1][Cl][=Branch2][NH1-1][SH1][NH1][Se+1][Na][C-1][OH1+1][S-1][N][OH0][O][S+1][OH0][C-1][=Se+1][P][F][=Ring2][=P][=Branch1][=SH1][#Branch1][OH0]', '[S+1][P][Si][=Se][Al][Branch1][=Ring1][=P][N-1][O+1][=Branch2][=Branch2][Ring1][=P+1][=S+1][N][#C][NH1][Cl+3][BH3-1][As][P+1][=N][#N][=Te+1][PH1][I+1][=Te+1][SeH1][NH1][#N][=Te+1][P][B][#Branch1][=Ring1][=Branch1][=Ring1][=SH1][#Branch2][=N+1][=Te+1][C-1][=P][Ring2][OH1+1][=O][O+1][H][Na][Cl+3][H][N][C-1][S][PH1][=Ring2][BH2-1][Br][=N-1][Te][SeH1][=N+1][=P][S+1][=NH2+1][O][S-1][=S][S+1][N-1][=S][S+1][Cl+3][CH1-1][As][=O][=Ring1][=Te+1][Ring1][Si]', '[=S+1][SeH1][F][O][BH1-1][=O][I+1][C+1][S-1][#N][Cl+3][I]', '[H][=P+1][C-1][=Ring1][NH1][O][As][=P][#Branch2][P+1][Na][=N][=Se][SeH1][N-1][P][B][Br][Se+1][Se+1][F][S+1][NH2+1][Cl][As][C][=P][Branch2][=P+1][S][BH3-1][=P+1][NH1+1][#C-1][=Te+1][=P+1][P+1][S-1][O+1][=As][C+1][As][Si][NH2+1][#Branch1][=P+1][=C][P][I][BH2-1][Cl][=S][NH1][=O][=As][SH1][Cl][F][#C-1][OH1+1][P][=N][#C][Te][#Branch1][Ring2][=Ring1][=Te+1][C-1][P][C+1][Br][=Branch2][=Se+1][P+1][=Ring1][CH1-1][P+1][Cl][=N+1][=Ring1][S-1][N][Al][=Ring1][F][OH1+1][Ring2][Branch2][N-1][S-1][C+1][=SH1][H][=As][Se+1][Branch2][S+1][O][=Ring1][B][Na][=N][N][NH1-1][=Se][BH3-1][I][CH1-1][Br][H][NH2+1][H][OH1+1][Se][Ring1][NH1+1][F][SeH1][P][Al][P][=O][#C-1][=Branch1][=NH2+1][=P][BH1-1][=P][N][#Branch2][OH1+1][Na][S-1][Cl][#Branch1][P+1][P+1][C][=Se ...
#
#  valid:  100.000 % | unique: 100.000 %
# [03:24:35] unsupported number of radical electrons 5
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x450>

# %%
out
# Out:
# [tensor([ 2, 69, 12, 56,  6, 46, 44, 12,  9, 36], device='cuda:0'),
#  tensor([35, 18, 74, 21, 57,  9, 23, 27, 15,  4], device='cuda:0'),
#  tensor([12, 37, 37, 43, 57, 33, 67, 63, 34, 33], device='cuda:0'),
#  tensor([50,  5,  4, 44, 47, 45, 64, 30, 28, 54], device='cuda:0'),
#  tensor([18, 17,  9, 13, 65,  0, 31, 44, 68, 14], device='cuda:0'),
#  tensor([58, 60, 67, 33, 50,  9,  6, 24, 20, 72], device='cuda:0'),
#  tensor([28,  4, 43, 73,  9, 53, 15,  2, 63, 44], device='cuda:0'),
#  tensor([34, 65, 23, 22, 17, 47, 43, 22,  8, 34], device='cuda:0'),
#  tensor([68, 47,  9, 74, 47, 13, 56,  1, 22, 43], device='cuda:0'),
#  tensor([30, 44, 21, 36, 32, 69, 54, 65, 50, 75], device='cuda:0'),
#  tensor([23, 16, 31, 59, 15, 38, 68, 71,  7, 76], device='cuda:0'),
#  tensor([72, 49, 40,  2, 14, 32,  5,  0,  0, 72], device='cuda:0'),
#  tensor([44, 55, 64, 48, 71, 77, 67, 51, 14, 57], device='cuda:0'),
#  tensor([50, 74, 76, 25, 52, 19, 47, 55, 27, 75], device='cuda:0'),
#  tensor([69,  6,  1, 75, 51, 17, 66,  9, 36, 65], device='cuda:0'),
#  tensor([55, 18,  3, 31, 52, 64, 54, 50, 27, 29], device='cuda:0'),
#  tensor([56, 66, 60, 59, 24, 62,  0,  8, 32, 66], device='cuda:0'),
#  tensor([ 9, 20, 29, 59, 56, 29, 17, 31, 70,  6], device='cuda:0'),
#  tensor([75,  2, 37, 64, 14, 31, 20, 19, 69, 16], device='cuda:0'),
#  tensor([15, 46, 46,  1, 62, 46, 20,  3, 76, 74], device='cuda:0'),
#  tensor([13,  3,  4, 19,  2, 25, 51, 34, 73, 11], device='cuda:0'),
#  tensor([51, 39, 63, 55, 32, 40, 70, 77, 63, 62], device='cuda:0'),
#  tensor([ 6, 38, 49, 63, 74, 76, 37, 11, 60,  0], device='cuda:0'),
#  tensor([45, 12, 27, 42,  3, 36, 47, 55, 36, 13], device='cuda:0'),
#  tensor([19, 61, 52, 58, 67, 37, 35,  0, 65, 73], device='cuda:0'),
#  tensor([60, 68, 12, 31, 22, 62, 13, 66, 32,  7], device='cuda:0'),
#  tensor([37, 72, 55, 24,  9, 60, 38, 66, 39, 41], device='cuda:0'),
#  tensor([32, 42, 15, 10,  0, 42, 73, 71, 69, 63], device='cuda:0'),
#  tensor([24,  2, 26, 10, 48, 54, 34, 53, 58, 33], device='cuda:0'),
#  tensor([75, 45, 27, 46, 49, 60, 14, 57, 54, 51], device='cuda:0'),
#  tensor([67, 23, 23, 75, 10, 19, 28, 17, 18,  8], device='cuda:0'),
#  tensor([32, 70, 74,  0,  2, 67, 36, 63, 25, 36], device='cuda:0'),
#  tensor([29, 20, 62, 54, 73, 42, 46, 69, 41, 12], device='cuda:0'),
#  tensor([45, 29,  6, 17, 25,  1, 38,  0, 76, 25], device='cuda:0'),
#  tensor([12, 34, 14, 49, 34, 47, 67, 49, 15, 42], device='cuda:0'),
#  tensor([21, 10, 28, 12, 46, 15, 57,  2, 66,  9], device='cuda:0'),
#  tensor([65, 54, 55, 37, 21, 72, 69, 17, 62, 17], device='cuda:0'),
#  tensor([12, 51, 58,  7, 53, 31, 53, 33, 49, 11], device='cuda:0'),
#  tensor([24, 32, 71, 62, 13, 54, 55, 51, 21, 39], device='cuda:0'),
#  tensor([44, 62, 34, 14, 35,  6,  1, 12, 26,  5], device='cuda:0'),
#  tensor([68, 40, 24, 63, 65, 14, 11, 50, 16,  5], device='cuda:0'),
#  tensor([58, 49, 16,  9, 28, 28,  0, 62, 38, 75], device='cuda:0'),
#  tensor([ 0,  3, 47, 60, 21, 64, 28, 70, 65, 19], device='cuda:0'),
#  tensor([24, 21, 10, 29, 52, 23, 21, 22, 76, 34], device='cuda:0'),
#  tensor([55, 30, 11, 16, 75, 45, 75, 15, 72, 72], device='cuda:0'),
#  tensor([72, 12, 10, 15, 18, 25, 68, 55,  2, 45], device='cuda:0'),
#  tensor([53, 17, 64,  0, 67, 58, 56, 71, 64, 58], device='cuda:0'),
#  tensor([70, 14, 68, 54, 77, 49, 37,  4, 57, 34], device='cuda:0'),
#  tensor([75, 30, 43,  1, 62, 64, 35, 16, 66, 54], device='cuda:0'),
#  tensor([20, 65, 46, 30, 60, 13, 44, 75, 66, 77], device='cuda:0'),
#  tensor([23, 64, 74, 53, 53, 63, 62, 27,  5, 17], device='cuda:0'),
#  tensor([28,  6, 55, 64, 42, 39, 38, 62, 39, 53], device='cuda:0'),
#  tensor([53, 14, 32, 24, 45, 18, 52,  1, 68, 48], device='cuda:0'),
#  tensor([49, 16, 26, 36, 40,  9, 66, 10,  9, 13], device='cuda:0'),
#  tensor([17, 69,  4, 62, 45, 17, 24, 19, 10, 35], device='cuda:0'),
#  tensor([56, 54, 25, 13,  4, 48, 11, 27, 43,  3], device='cuda:0'),
#  tensor([19,  2,  9, 26, 72, 57, 71, 59, 70, 63], device='cuda:0'),
#  tensor([57, 56, 69, 53,  9, 47, 56, 35, 26, 29], device='cuda:0'),
#  tensor([30, 65,  8,  6, 33, 25, 62, 10, 55, 37], device='cuda:0'),
#  tensor([53, 76,  0, 68, 31, 27, 14, 56, 18,  4], device='cuda:0'),
#  tensor([75, 47, 54, 35, 28, 48, 10, 52, 76,  2], device='cuda:0'),
#  tensor([30, 12, 30, 44, 65, 77, 27, 27, 26, 73], device='cuda:0'),
#  tensor([58, 27,  4, 49, 25, 61, 19, 15, 32, 30], device='cuda:0'),
#  tensor([77,  5, 42, 23, 71, 14, 68, 53, 63,  9], device='cuda:0'),
#  tensor([13, 67, 27, 71, 69, 22, 34, 23, 48,  0], device='cuda:0'),
#  tensor([ 2, 70, 73, 59, 40, 47,  2, 77, 48, 26], device='cuda:0'),
#  tensor([28, 49, 45,  2, 62,  7,  9, 66, 31,  6], device='cuda:0'),
#  tensor([55, 49, 57, 18,  2, 67, 19, 42, 19, 46], device='cuda:0'),
#  tensor([26, 12, 61, 49, 71, 74, 20, 70, 64, 26], device='cuda:0'),
#  tensor([26, 60, 14, 68,  8, 60, 26,  8, 50, 74], device='cuda:0'),
#  tensor([35, 71, 67, 50, 15, 30, 74, 75, 23, 72], device='cuda:0'),
#  tensor([74, 47, 29, 25, 12, 16, 29, 40, 10, 42], device='cuda:0'),
#  tensor([73,  5, 15, 14, 66, 37, 50, 74, 26, 68], device='cuda:0'),
#  tensor([49, 73, 76, 24,  3, 57, 75, 14, 23, 21], device='cuda:0'),
#  tensor([34, 22, 61, 60, 76, 76, 25, 59, 42, 15], device='cuda:0'),
#  tensor([ 7, 65, 33,  3, 68, 21, 15, 75, 62, 41], device='cuda:0'),
#  tensor([51,  4, 62, 51, 10,  4, 62, 16, 51, 71], device='cuda:0'),
#  tensor([60, 65, 60, 54, 62, 38, 72, 40,  8,  4], device='cuda:0'),
#  tensor([36, 10, 64, 72,  4, 11, 51, 13, 54, 75], device='cuda:0'),
#  tensor([40, 56, 43, 61, 64, 75,  2, 14, 47, 17], device='cuda:0'),
#  tensor([27, 29, 59, 37, 12, 46, 22,  0, 14, 76], device='cuda:0'),
#  tensor([65, 36, 11, 39, 76,  8, 56, 33, 49, 42], device='cuda:0'),
#  tensor([12, 57, 53, 38,  4, 18, 63, 48, 16, 46], device='cuda:0'),
#  tensor([64, 38, 65, 22, 16,  7, 21, 25, 55, 25], device='cuda:0'),
#  tensor([44,  5, 51, 16, 27,  6, 55, 77, 38, 12], device='cuda:0'),
#  tensor([ 6,  2,  2, 52, 37, 22, 72, 70, 66, 33], device='cuda:0'),
#  tensor([62,  2, 62, 44, 31,  0, 47, 77, 11, 57], device='cuda:0'),
#  tensor([49, 67, 68, 68, 52, 39, 40, 40,  6, 29], device='cuda:0'),
#  tensor([26, 42, 42, 28, 15, 73,  5, 44,  1, 19], device='cuda:0'),
#  tensor([67, 68, 37, 49, 51, 60, 76, 70, 26, 67], device='cuda:0'),
#  tensor([ 4, 22, 30, 45, 65, 19, 39, 34,  9, 21], device='cuda:0'),
#  tensor([25,  2, 35, 58, 70,  9, 55, 12, 29, 22], device='cuda:0'),
#  tensor([38, 52,  2, 64, 67, 61, 24, 56, 65, 16], device='cuda:0'),
#  tensor([46, 62,  2, 67, 58, 40, 76, 29, 25, 10], device='cuda:0'),
#  tensor([14, 49, 56, 62, 24, 28, 24, 40, 51, 40], device='cuda:0'),
#  tensor([62, 77,  4, 76, 30, 22, 16, 47, 31, 63], device='cuda:0'),
#  tensor([10, 57, 39, 12,  1, 43, 73, 32, 54, 59], device='cuda:0'),
#  tensor([49, 52, 47, 17, 43, 61, 44, 61, 67, 35], device='cuda:0'),
#  tensor([42, 70, 31,  9,  5, 22, 52, 39, 75, 50], device='cuda:0'),
#  tensor([32, 51, 60, 49,  2, 31, 41, 11,  3, 46], device='cuda:0'),
#  tensor([76, 59, 61, 35, 47, 38, 59, 15, 35, 27], device='cuda:0'),
#  tensor([15, 59, 21, 23, 17, 33, 32,  6, 16, 24], device='cuda:0'),
#  tensor([15, 25, 42, 33, 48,  8,  3, 17, 38, 69], device='cuda:0'),
#  tensor([11, 28, 77, 18, 57, 27,  7, 22, 56, 77], device='cuda:0'),
#  tensor([36, 56, 74, 39, 52, 42, 50, 23,  0, 62], device='cuda:0'),
#  tensor([77,  1,  7, 67, 41, 59, 14, 45, 39, 40], device='cuda:0'),
#  tensor([40,  4, 77, 71, 55, 43, 36,  7, 39, 50], device='cuda:0'),
#  tensor([60,  8, 37,  2, 37,  8, 25, 30, 36, 49], device='cuda:0'),
#  tensor([48, 27, 65, 64, 14,  1,  7,  4, 65, 21], device='cuda:0'),
#  tensor([76, 76, 25,  7, 54, 26,  6,  0, 28, 68], device='cuda:0'),
#  tensor([32, 63, 69, 64, 38, 36, 35,  5,  6, 71], device='cuda:0'),
#  tensor([66, 26,  0, 67, 30, 51, 68, 62, 26, 16], device='cuda:0'),
#  tensor([61, 17, 71, 36, 36, 68, 23, 51, 30,  8], device='cuda:0'),
#  tensor([68, 68, 31, 23, 60, 67, 40, 47, 46, 65], device='cuda:0'),
#  tensor([21, 55, 49,  8, 64, 67, 37, 63, 42, 29], device='cuda:0'),
#  tensor([55, 15, 24, 63, 64, 24,  5,  9, 10, 24], device='cuda:0'),
#  tensor([47, 19, 24, 31, 16, 60,  7, 30, 10, 41], device='cuda:0'),
#  tensor([32, 72,  6, 50, 19, 26, 65, 57, 74, 53], device='cuda:0'),
#  tensor([23,  0, 35, 14, 29,  0, 50, 53, 18, 12], device='cuda:0'),
#  tensor([75, 34, 40, 34, 58, 58,  5, 25, 67, 60], device='cuda:0'),
#  tensor([59, 44, 19, 23, 71, 70,  2, 29,  8, 19], device='cuda:0'),
#  tensor([48, 12, 10, 57, 44, 59, 14, 66,  2, 41], device='cuda:0'),
#  tensor([45, 37, 43, 17, 30, 44, 53, 19, 50,  1], device='cuda:0'),
#  tensor([29, 36,  6, 54, 21, 63, 71, 55, 26, 74], device='cuda:0'),
#  tensor([10, 56,  6, 57, 31, 29, 56, 30, 21, 18], device='cuda:0'),
#  tensor([72,  9, 16, 56, 43, 23, 72, 57, 42, 33], device='cuda:0'),
#  tensor([66, 53, 27, 44, 67, 62,  1, 49, 19, 47], device='cuda:0'),
#  tensor([71, 24,  9, 55, 63,  2, 22, 23, 36, 17], device='cuda:0'),
#  tensor([33,  1, 10, 35, 59, 58, 58, 18, 60, 48], device='cuda:0'),
#  tensor([22, 61, 67, 24, 44, 33, 51, 31, 27, 72], device='cuda:0'),
#  tensor([28, 52, 48, 61, 11, 25, 31, 31, 71, 24], device='cuda:0'),
#  tensor([75, 46, 41, 44, 10, 77, 39, 46, 18,  6], device='cuda:0'),
#  tensor([48, 15, 75,  3, 62, 75, 10, 60, 28, 19], device='cuda:0'),
#  tensor([37, 17, 15, 13, 16, 16, 57, 56,  3, 54], device='cuda:0'),
#  tensor([10, 11, 55, 40, 68, 50, 67, 24,  7, 52], device='cuda:0'),
#  tensor([48, 18, 44, 12, 46, 57, 75, 56, 56, 73], device='cuda:0'),
#  tensor([67, 13,  4, 42, 12, 73, 14, 34, 63, 25], device='cuda:0'),
#  tensor([62, 29, 31, 53, 42, 41, 76,  7, 18, 39], device='cuda:0'),
#  tensor([43, 69, 10, 62, 59,  1, 39, 26, 29, 54], device='cuda:0'),
#  tensor([40, 68, 60, 69, 38, 21, 31, 34, 68, 51], device='cuda:0'),
#  tensor([39, 66, 12, 23, 43, 56, 21, 17, 16, 52], device='cuda:0')]

# %%
# Out:
# 14

# %%
a
